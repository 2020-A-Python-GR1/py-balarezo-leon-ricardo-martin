# %%
from IPython.display import clear_output
import numpy as np
from time import sleep
import math
from scipy import ndimage
from scipy import misc
import random
import matplotlib.pyplot as plt


mapache = misc.face()
fila1 = mapache[0:256]

f1 = np.hsplit(mapache[0:256], 4)
f2 = np.hsplit(mapache[256:512], 4)
f3 = np.hsplit(mapache[512:768], 4)

c1 = f1[0]
c2 = f1[1]
c3 = f1[2]

c4 = f2[0]
c5 = f2[1]
c6 = f2[2]

c7 = f3[0]
c8 = f3[1]
c9 = f3[2]

puzzle = [c1,c2,c3,c4,c5,c6,c7,c8,c9]

random.shuffle(puzzle, random.random)

# %%
#np.split(p1,3)

# %%
#mapache.shape
plt.imshow(c1)
    #plt.imshow(img2)
    #plt.imshow(img3)
plt.show()

# %%
p1 = np.hsplit(fila1, 4)

# %%
tabla=plt.figure(figsize=(10, 10))

columns = 3
rows = 3

fig_completa = np.stack((f1,f2,f3))
#for i in range(1, columns*rows +1):

for i in range(1, 4):
    img1 = f1[i]
    #img2 = f2[i]
    #img3 = f3[i]
    tabla.add_subplot(1, 3, i)
    plt.imshow(img1)
    #plt.imshow(img2)
    #plt.imshow(img3)
plt.show()

# %%
tabla=plt.figure(figsize=(10, 10))

for i in range(1, 4):
    img = f2[i]
    tabla.add_subplot(1, 3, i)
    plt.imshow(img)
    
plt.show()

# %%
tabla=plt.figure(figsize=(10, 10))

for i in range(1, 4):
    img = f3[i]
    tabla.add_subplot(1, 3, i)
    plt.imshow(img)
plt.show()

# %%
#plt.figure(figsize=(8,8))


#print(puzzle)


import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,8))


fig.add_subplot(3,3,1)
plt.imshow(puzzle[0])

fig.add_subplot(3,3,2)
plt.imshow(puzzle[1])

fig.add_subplot(3,3,3)   
plt.imshow(puzzle[2])

fig.add_subplot(3,3,4)   
plt.imshow(puzzle[3])

fig.add_subplot(3,3,5)
plt.imshow(puzzle[4])

fig.add_subplot(3,3,6)
plt.imshow(puzzle[5])

fig.add_subplot(3,3,7)
plt.imshow(puzzle[6])

fig.add_subplot(3,3,8)
plt.imshow(puzzle[7])

fig.add_subplot(3,3,9)
plt.imshow(puzzle[8])

plt.show()

# %%
##no tocar
def mostrar_puzzel():
    fig = plt.figure(figsize=(12, 12))
    
    for i in range(1,10):
        #print(i)
        fig.add_subplot(3,3,i)
        plt.imshow(puzzle[i-1])
    plt.show()

#intercambiar(1,2)

# %%
mostrar_puzzel()

# %%
#print(puzzle)

# %%
#ejem = np.arange(1,10)

# %%
#ejem

# %%
#random.shuffle(ejem,random.random)

# %%
#ejem

# %%
def cambio(arr, i1, i2):
    
    arreglo_swap = arr
    
    #arreglo_swap[i1-1]
    #arreglo_swap[i2-1]
    #print(f"ha seleccionado los indices {arreglo_swap[i1-1]}, y {arreglo_swap[i2-1]}")
    #print(f"realizando el cambio...")
    
    temp = arreglo_swap[i1-1]
    arreglo_swap[i1-1] = arreglo_swap[i2-1]
    arreglo_swap[i2-1] = temp
    #print(f"el arreglo nuevo es {arreglo_swap}")
    mostrar_puzzel()

# %%
cambio(puzzle, 2,5)

# %%
#ejem
