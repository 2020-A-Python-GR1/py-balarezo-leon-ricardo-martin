# %%
#imports
import numpy as np
import scipy
from scipy import misc
import matplotlib.pyplot as plt

# %%
mapache = misc.face()

# %%
plt.imshow(mapache)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.imshow(mapache[0:256])
plt.show

plt.imshow(mapache[256:512])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print(mapache.shape)
# Out:
# (768, 1024, 3)

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
fila1 = mapache[0:256]
fila2 = mapache[256:512]
fila3 = mapache[512:768]

# %%
#plt.imshow(fila1)

fila1



plt.imshow(fila1[0:256])

# %%
plt.imshow(fila2)

# %%
plt.imshow(fila3)

# %%
import numpy as np
import matplotlib.pyplot as plt

w=3
h=3
fig=plt.figure(figsize=(10, 10))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
fila1.shape
# Out:
# (256, 1024, 3)

# %%
#juego = Puzzle()

# %%
#Puzzle()
